# %%
print('''Netflix Content Strategy Analysis

 Objective
Analyze Netflix content dataset to:
- Compare Movies vs TV Shows distribution
- Identify most common genres
- Analyze content release trends by year
- Provide strategic recommendations''')


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
# Out:
# Netflix Content Strategy Analysis
#
#  Objective
# Analyze Netflix content dataset to:
# - Compare Movies vs TV Shows distribution
# - Identify most common genres
# - Analyze content release trends by year
# - Provide strategic recommendations

# %%
df = pd.read_csv("C:/Users/HP/Downloads/netflix_dataset_100.csv")
df.head()
# Out:
#    show_id     type        genre  release_year    country  duration_min
# 0        1  TV Show       Comedy          2022         UK           107
# 1        2    Movie       Action          2021      India           131
# 2        3  TV Show  Documentary          2021     Canada           173
# 3        4  TV Show       Comedy          2017  Australia           118
# 4        5  TV Show      Romance          2017        USA           146

# %%
df.info()
df.isnull().sum()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       100 non-null    int64
#  1   type          100 non-null    object
#  2   genre         100 non-null    object
#  3   release_year  100 non-null    int64
#  4   country       100 non-null    object
#  5   duration_min  100 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 4.8+ KB
#           show_id  release_year  duration_min
# count  100.000000    100.000000    100.000000
# mean    50.500000   2019.050000    121.670000
# std     29.011492      2.512092     36.501572
# min      1.000000   2015.000000     62.000000
# 25%     25.750000   2017.000000     89.750000
# 50%     50.500000   2019.000000    118.000000
# 75%     75.250000   2021.000000    157.250000
# max    100.000000   2023.000000    179.000000

# %%
type_counts = df['type'].value_counts()

plt.figure()
type_counts.plot(kind='bar')
plt.title("Movies vs TV Shows Distribution")
plt.xlabel("Type")
plt.ylabel("Count")
plt.show()

# %%
genre_counts = df['genre'].value_counts().head(10)

plt.figure()
genre_counts.plot(kind='bar')
plt.title("Top 10 Genres")
plt.xlabel("Genre")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
year_counts = df['release_year'].value_counts().sort_index()

plt.figure()
year_counts.plot(kind='line')
plt.title("Content Release Trend by Year")
plt.xlabel("Year")
plt.ylabel("Number of Releases")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=type_counts.index, y=type_counts.values)
plt.title("Movies vs TV Shows Distribution", fontsize=14, fontweight='bold')
plt.show()

# %%
type_year = df.groupby(['release_year', 'type']).size().unstack()

type_year.plot()
plt.title("Movies vs TV Shows Trend Over Years")
plt.show()

# %%
print("""Strategic Recommendations

Based on the analysis:

1. Netflix should continue investing in high-performing genres such as Drama and Action.
2. Increasing focus on TV Shows can improve long-term subscriber retention.
3. Content diversification into emerging genres can help attract niche audiences.
4. Sustaining consistent yearly releases will maintain platform growth momentum.""")
# Out:
# Strategic Recommendations
#
# Based on the analysis:
#
# 1. Netflix should continue investing in high-performing genres such as Drama and Action.
# 2. Increasing focus on TV Shows can improve long-term subscriber retention.
# 3. Content diversification into emerging genres can help attract niche audiences.
# 4. Sustaining consistent yearly releases will maintain platform growth momentum.
